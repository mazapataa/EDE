# %%
import numpy as np
import sys
import os
import time

#CLASS
import classy
import matplotlib.pyplot as plt

# %%
# Fixed parameters
w0 = -0.9
h = 0.7
Omega_ede_values = np.linspace(0.001, 0.09, 15)  
As = 2.100549e-09
ns= 0.9660499
omega_cdm = 0.1201075
omega_b = 0.02238280
l_max_scalars = 2500
l_max_tensors = 600

# %%
krange2 = np.logspace(np.log10(1e-4), np.log10(1e-3), num=40, endpoint=False)
krange3 = np.logspace(np.log10(1e-3), np.log10(1e-2), num=60, endpoint=False)
krange4 = np.logspace(np.log10(1e-2), np.log10(1e-1), num=80, endpoint=False)
krange5 = np.logspace(np.log10(1e-1), np.log10(1), num=100, endpoint=False)
krange6 = np.logspace(np.log10(1), np.log10(10), num=120, endpoint=False)

k = np.concatenate((krange2, krange3, krange4, krange5, krange6))

# %%
import numpy as np

# number of parameters, samples and number of job arrays.
n_samples = 20
omega_b_arr = np.tile(omega_b,  n_samples)
omega_cdm_arr = np.tile(omega_cdm, n_samples)
h_arr = np.tile(h, n_samples)
ns_arr = np.tile(ns, n_samples)
As_arr = np.tile(As, n_samples)
z_arr = np.linspace(0, 5, n_samples)

w_arr = np.linspace(-0.7, -1.3, n_samples)
Omega_ede_arr = np.linspace(0.001, 0.09, n_samples)

# %%
def linear_generation(i):

#   Define your cosmology (what is not specified will be set to CLASS default parameters)

    cosmo.set({'output': 'tCl mPk','P_k_max_1/Mpc':50.,'z_max_pk':5.0,
            'h':h_arr[i],'N_ur':2.0308,'N_ncdm':1,
            'cs2_fld':1.,
            'use_ppf': 'yes',
            'tol_initial_Omega_r': 0.1,
            'fluid_equation_of_state': 'EDE',
            'Omega_EDE': Omega_ede_arr[i],
            'Omega_Lambda': 0.0,
            'gauge': 'Newtonian',
            'w0_fld':w_arr[i],
            'Omega_Lambda':0.,
            'omega_b':omega_b_arr[i],'omega_cdm':omega_cdm_arr[i],
            'A_s':As_arr[i],'n_s':ns_arr[i]})
    cosmo.compute()

    z = np.linspace(0.0, 5.0, 50)

    if z_arr[i] not in z:
        index_remove = np.where(z_arr[i] < z)[0][0] #The nearest redshift to the one will be inserted
        z = np.delete(z, index_remove)
        z = np.sort(np.insert(z, 1, z_arr[i]))

    z_pos = np.where(z == z_arr[i])[0][0]  #Index of z_i in z array.


    #Linear DS
    P_lin = np.array([[cosmo.pk(ki, zi)*h_arr[i]**3.0 for ki in k*h_arr[i]] for zi in z])
    sigma_8 = cosmo.sigma8()

    #Linear LCDM
    cosmo_lcdm = classy.Class()

    cosmo_lcdm.set({'output':'tCl mPk','P_k_max_1/Mpc':50,'z_max_pk':5.0,
           'h':h_arr[i],'N_ur':2.0308,'N_ncdm':1,
           'gauge':'Newtonian',
           'omega_b':omega_b_arr[i],'omega_cdm':omega_cdm_arr[i],
           'A_s':As_arr[i],'n_s':ns_arr[i]})

    cosmo_lcdm.compute()

    Plcdm = np.array([[cosmo_lcdm.pk(ki, zi)*h_arr[i]**3.0 for ki in k*h_arr[i]] for zi in z])
    sigma_8_lcdm = cosmo_lcdm.sigma8()
    

    return P_lin, Plcdm, sigma_8, sigma_8_lcdm

# %%
cosmo = classy.Class()
linear_ede = []
linear_lcdm = []
for i in range(len(Omega_ede_arr)): 
    P_lin_i, Plcdm_i, sigma_8_i, sigma_8_lcdm_i = linear_generation(i) 
    linear_ede.append(P_lin_i[0])
    linear_lcdm.append(Plcdm_i[0])

linear_lcdm=np.array(linear_lcdm)
linear_ede=np.array(linear_ede)

# %%
cmap = plt.get_cmap('winter')
colors = [cmap(i / (len(Omega_ede_arr) - 1)) for i in range(len(Omega_ede_arr))]



fig, ax = plt.subplots(figsize=(12, 7))

ax.set_xscale('log')
for i in range(len(Omega_ede_arr)):
    ax.plot(k,linear_ede[i]/linear_lcdm[i],color=colors[i])

ax.set_xlabel(r'$k \,\, [h/\mathrm{Mpc}]$', fontsize=14)
ax.set_ylabel(r'$P_{EDE}/P_{\Lambda \text{CDM}}$', fontsize=14)
#ax.set_title(r'Matter Power Spectrum $P(k)$' % Omega_ede, fontsize=14)
ax.set_ylim(0.4,1.0)
ax.grid(True, which="both", alpha=0.3)
norm = plt.Normalize(vmin=min(Omega_ede_arr), vmax=max(Omega_ede_arr))
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])  
cbar = plt.colorbar(sm, ax=ax, label=r'$\Omega_{\mathrm{EDE}}$')

plt.show()

# %%
Omega_ede_arr
# Out:
# array([0.001     , 0.00735714, 0.01371429, 0.02007143, 0.02642857,
#        0.03278571, 0.03914286, 0.0455    , 0.05185714, 0.05821429,
#        0.06457143, 0.07092857, 0.07728571, 0.08364286, 0.09      ])

# %%
linear_generation(1)
# Out:
# (array([[390.5686346 , 397.68913947, 404.94690113, ..., 290.27807279,
#          285.07801686, 279.95508304],
#         [380.33272522, 387.26292653, 394.32659882, ..., 278.19765448,
#          273.18814996, 268.2543255 ],
#         [316.25367727, 321.99777381, 327.85202759, ..., 207.20921879,
#          203.34426246, 199.54506009],
#         ...,
#         [ 22.63529634,  23.03543444,  23.44332274, ...,   4.10110844,
#            3.94789768,   3.80051911],
#         [ 21.88551559,  22.27214779,  22.66627617, ...,   3.93519328,
#            3.78735203,   3.64515082],
#         [ 21.17218404,  21.5460291 ,  21.92710628, ...,   3.77969016,
#            3.63693543,   3.49963778]]),
#  array([[473.41211026, 481.91587948, 490.56512875, ...,  75.4726534 ,
#           72.33683525,  69.32612036],
#         [461.5454322 , 469.83583088, 478.2679781 , ...,  73.58119251,
#           70.5239628 ,  67.58870107],
#         [384.41577132, 391.3193477 , 398.34040665, ...,  61.28704161,
#           58.74062242,  56.29579247],
#         ...,
#         [ 23.5463015 ,  23.96099271,  24.38272233, ...,   3.74391099,
#            3.588355  ,   3.43900492],
#         [ 22.7488097 ,  23.14915048,  23.55629184, ...,   3.61643253,
#            3.46617315,   3.32190837],
#         [ 21.99118842,  22.37790914,  22.77118079, ...,   3.49533346,
#            3.35010562,   3.21067166]]),
#  0.7161928453627796,
#  0.8309433277391158)

# %%
cmap = plt.get_cmap('winter')
colors = [cmap(i / (len(Omega_ede_values) - 1)) for i in range(len(Omega_ede_values))]

fig, ax = plt.subplots(figsize=(12, 7))

for i, Omega_ede in enumerate(Omega_ede_values):
     cosmo = classy.Class()
     cosmo.set({
        'use_ppf': 'yes',
        'tol_initial_Omega_r': 0.1,
        'fluid_equation_of_state': 'EDE',
        'A_s': As,
        'n_s': ns,
        'h': h,
        'w0_fld': w0,
        'Omega_EDE': Omega_ede,
        'Omega_Lambda': 0.0,
        'gauge': 'Newtonian',
        'output': 'tCl mPk',
        'P_k_max_1/Mpc': 50.,
        'z_max_pk': 5.0,
        'k_output_values': '0.5',
        'non linear': 'halofit'
    })
     cosmo.compute()
     ba = cosmo.get_background()
     omega_de = ba['(.)rho_fld'] / ba['(.)rho_crit']
   
    
     ax.plot(ba['z'], omega_de, color=colors[i], lw=2)
    


ax.set_xlim(0, 3)
ax.set_ylim(0, 0.8)
ax.set_xlabel('$z$', fontsize=14)
ax.set_ylabel(r'$\Omega_{DE}(z)$', fontsize=14)
ax.grid(True, alpha=0.3)
ax.set_title('Early Dark Energy', fontsize=14)


norm = plt.Normalize(vmin=min(Omega_ede_values), vmax=max(Omega_ede_values))
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])  
cbar = plt.colorbar(sm, ax=ax, label=r'$\Omega_{\mathrm{EDE}}$')  

plt.tight_layout()
plt.show()

# %%
l_max_scalars = 2500
l_max_tensors = 600

lcdm_params = {
    'h': 0.67810,
    'omega_b': 0.02238280,
    'omega_cdm': 0.1201075,
    'A_s': 2.100549e-09,
    'tau_reio': 0.05430842,
    'n_s': 0.9660499,  # Needed for accurate spectrum
    'output': 'tCl,pCl,lCl,mPk',
    'modes': 's,t',
    'lensing': 'yes',
    'r': 0.1,
    'n_t': 0,
    'l_max_scalars': l_max_scalars,
    'l_max_tensors': l_max_tensors
}


cosmo_lcdm = classy.Class()
cosmo_lcdm.set(lcdm_params)
cosmo_lcdm.compute()


cl_lcdm = cosmo_lcdm.lensed_cl(l_max_scalars)
ell_lcdm = cl_lcdm['ell']
cl_tt_lcdm = 1e10 * ell_lcdm * (ell_lcdm + 1) * cl_lcdm['tt'] / (2 * np.pi)

# %%
cmap = plt.get_cmap('winter')
colors = [cmap(i / (len(Omega_ede_values) - 1)) for i in range(len(Omega_ede_values))]

fig, ax = plt.subplots(figsize=(12, 7))

ax.set_xlim(2, 2500)
ax.set_xlabel(r"$\ell$", fontsize=14)
ax.set_ylabel(r"$\ell (\ell+1) \Delta C_\ell/C_\ell^{\Lambda \text{CDM}} / 2 \pi$", fontsize=14)
ax.set_title("CMB Temperature Spectrum for Different EDE}", fontsize=14)
ax.grid(True, which="both", alpha=0.3)

for i, Omega_ede in enumerate(Omega_ede_values):
    common_settings = {
        'use_ppf': 'yes',
        'tol_initial_Omega_r': 0.1,
        'fluid_equation_of_state': 'EDE',
        'A_s': 2.100549e-09,
        'n_s': 0.9660499,
        'h': h,
        'w0_fld': w0,
        'Omega_EDE': Omega_ede,
        'Omega_Lambda': 0.0,
        'gauge': 'Newtonian',
        'non linear': 'halofit'
    }

    M = classy.Class()

    M.set({
        **common_settings,
        'output': 'tCl,pCl,lCl',
        'modes': 's,t',
        'lensing': 'yes',
        'r': 0.1,
        'n_t': 0,
        'l_max_scalars': l_max_scalars,
        'l_max_tensors': l_max_tensors
    })
    M.compute()

    cl_lensed = M.lensed_cl(l_max_scalars)
    ell = cl_lensed['ell']
    factor = 1e10 * ell * (ell + 1) / (2 * np.pi)
    cl_tt = factor * cl_lensed['tt']

    ax.semilogx(ell,cl_tt/cl_tt_lcdm-1, color=colors[i], lw=1.5)

    M.struct_cleanup()
    M.empty()

# Add colorbar
norm = plt.Normalize(vmin=min(Omega_ede_values), vmax=max(Omega_ede_values))
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])  #
cbar = fig.colorbar(sm, ax=ax, label=r'$\Omega_{\mathrm{EDE}}$')

plt.tight_layout()
plt.show()
# Out:
# /var/folders/3q/y_52zqp93p75bklmln9pnttm0000gn/T/ipykernel_1932/1956211746.py:46: RuntimeWarning: invalid value encountered in divide
#   ax.semilogx(ell,cl_tt/cl_tt_lcdm-1, color=colors[i], lw=1.5)

# %%
k = np.logspace(-4, 0, 500)
pk_lcdm = np.array([cosmo_lcdm.pk(ki, 0) for ki in k])

# %%
fig, ax = plt.subplots(figsize=(12, 7))


ax.set_xscale('log')
ax.set_yscale('log')

for i, Omega_ede in enumerate(Omega_ede_values):
     cosmo = classy.Class()
     cosmo.set({
        'use_ppf': 'yes',
        'tol_initial_Omega_r': 0.1,
        'fluid_equation_of_state': 'EDE',
        'A_s': 2.100549e-09,
        'n_s': 0.9660499,
        'h': h,
        'w0_fld': w0,
        'Omega_EDE': Omega_ede,
        'Omega_Lambda': 0.0,
        'gauge': 'Newtonian',
        'output': 'tCl mPk',
        'P_k_max_1/Mpc': 50.,
        'z_max_pk': 5.0,
        'k_output_values': '0.5',
        'non linear': 'halofit'
    })
     cosmo.compute()
     Pk = np.array([cosmo.pk(ki, 0) for ki in k])
     ax.plot(k,Pk, color=colors[i], lw=2)

ax.set_xlabel(r'$k \,\, [h/\mathrm{Mpc}]$', fontsize=14)
ax.set_ylabel(r'$P_{EDE}(k)$', fontsize=14)
ax.set_title(r'Matter Power Spectrum EDE' % Omega_ede, fontsize=14)
#ax.set_ylim(0.5,1.5)
ax.grid(True, which="both", alpha=0.3)

# Create colorbar
norm = plt.Normalize(vmin=min(Omega_ede_values), vmax=max(Omega_ede_values))
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])  
cbar = plt.colorbar(sm, ax=ax, label=r'$\Omega_{\mathrm{EDE}}$')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 7))

ax.set_xscale('log')
ax.set_yscale('log')

for i, Omega_ede in enumerate(Omega_ede_values):
     cosmo = classy.Class()
     cosmo.set({
        'use_ppf': 'yes',
        'tol_initial_Omega_r': 0.1,
        'fluid_equation_of_state': 'EDE',
        'A_s': 2.100549e-09,
        'n_s': 0.9660499,
        'h': h,
        'w0_fld': w0,
        'Omega_EDE': Omega_ede,
        'Omega_Lambda': 0.0,
        'gauge': 'Newtonian',
        'output': 'tCl mPk',
        'P_k_max_1/Mpc': 50.,
        'z_max_pk': 5.0,
        'k_output_values': '0.5',
        'non linear': 'halofit'
    })
     cosmo.compute()
     Pk = np.array([cosmo.pk(ki, 0) for ki in k])
     ratio_Pk = pk_lcdm/Pk
     ax.plot(k, ratio_Pk, color=colors[i], lw=2)

ax.set_xlabel(r'$k \,\, [h/\mathrm{Mpc}]$', fontsize=14)
ax.set_ylabel(r'$P_{EDE}/P_{\Lambda \text{CDM}}$', fontsize=14)
ax.set_title(r'Matter Power Spectrum $P(k)$' % Omega_ede, fontsize=14)
#ax.set_ylim(0.5,1.5)
ax.grid(True, which="both", alpha=0.3)

# Create colorbar
norm = plt.Normalize(vmin=min(Omega_ede_values), vmax=max(Omega_ede_values))
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])  
cbar = plt.colorbar(sm, ax=ax, label=r'$\Omega_{\mathrm{EDE}}$')

plt.show()

# %%
cosmo.sigma8()
# Out:
# 0.533681984075351

# %%
z = np.linspace(0.0, 5.0, 50)
krange2 = np.logspace(np.log10(1e-4), np.log10(1e-3), num=40, endpoint=False)
krange3 = np.logspace(np.log10(1e-3), np.log10(1e-2), num=60, endpoint=False)
krange4 = np.logspace(np.log10(1e-2), np.log10(1e-1), num=80, endpoint=False)
krange5 = np.logspace(np.log10(1e-1), np.log10(1), num=100, endpoint=False)
krange6 = np.logspace(np.log10(1), np.log10(10), num=120, endpoint=False)

k = np.concatenate((krange2, krange3, krange4, krange5, krange6))
#Linear DS
P_lin = np.array([[cosmo.pk(ki, zi)*h**3.0 for ki in k*h] for zi in z])
